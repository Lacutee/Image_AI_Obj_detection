# %% [markdown]
# <a href="https://www.kaggle.com/ridhomuhammad/image-ai-test?scriptVersionId=84864893" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !cp -r /kaggle/input ./

# %%
# !ls -l ./input/spik-imageai/headset/models!

# %%
head_path= "./input/rnnhand/RNN-Hand"
train_path= "./input/rnnhand/RNN-Hand/train"
test_path= "./input/rnnhand/RNN-Hand/test"
train_anot_path= "./input/rnnhand/RNN-Hand/train/annotations"
test_anot_path= "./input/rnnhand/RNN-Hand/test/annotations"
train_img_path= "./input/rnnhand/RNN-Hand/train/images"
models_path="./input/yolo-v3-test/yolo.h5"

# %%
# !ls ./input/rnnhand/RNN-Hand/train/images

# %%
# !pip install imageai

# %%
from imageai.Detection.Custom import DetectionModelTrainer

trainer = DetectionModelTrainer()
trainer.setModelTypeAsYOLOv3()
trainer.setDataDirectory(data_directory=head_path)
trainer.setTrainConfig(object_names_array=["hand"], batch_size=4, num_experiments=44)
# In the above,when training for detecting multiple objects,
#set object_names_array=["object1", "object2", "object3",..."objectz"]
trainer.trainModel()

# %%
metrics = trainer.evaluateModel(model_path="./input/spik-imageai/headset/models/detection_model-ex-029--loss-0017.674.h5", json_path="./input/spik-imageai/headset/json/detection_config.json", iou_threshold=0.5, object_threshold=0.3, nms_threshold=0.5)

# %%
import os
os.listdir('./input/rnnhand/RNN-Hand/models/')

# %%
# !cp ./input/rnnhand/RNN-Hand/models/detection_model-ex-029--loss-0019.187.h5 ./input/

# %%
from imageai.Detection.Custom import CustomObjectDetection

detector = CustomObjectDetection()
detector.setModelTypeAsYOLOv3()
detector.setModelPath("./input/rnnhand/RNN-Hand/models/detection_model-ex-029--loss-0019.187.h5")
detector.setJsonPath("./input/rnnhand/RNN-Hand/json/detection_config.json")
detector.loadModel()
detections = detector.detectObjectsFromImage(input_image="../input/rnnhand/RNN-Hand/test/images/VOC2007_506.jpg", output_image_path="./input/holo2-detected.jpg", minimum_percentage_probability=30)
for detection in detections:
    print(detection["name"], " : ", detection["percentage_probability"], " : ", detection["box_points"])

# %%
# !ls ../input/rnnhand/RNN-Hand/test/images
